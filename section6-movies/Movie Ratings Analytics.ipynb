# %%
#Categorical Variables

import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/kevin/Documents/pythonudemy/pythonudemy'

# %%
movies = pd.read_csv("Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating'\
                  ,'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
#note on data types 

#CriticRating and AudienceRating is an int64 (number)
#Year is an int64 (number), year is a catagorical variable

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null object
# CriticRating       559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMillions     559 non-null int64
# Year               559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre.unique()
# Out:
# array(['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance',
#        'Thriller'], dtype=object)

# %%
movies.Genre.nunique()
# Out:
# 7

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# CriticRating       559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMillions     559 non-null int64
# Year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.unique()
# Out:
# [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]
# Categories (7, object): [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions
# count    559.000000       559.000000      559.000000
# mean      47.309481        58.744186       50.236136
# std       26.413091        16.826887       48.731817
# min        0.000000         0.000000        0.000000
# 25%       25.000000        47.000000       20.000000
# 50%       46.000000        58.000000       35.000000
# 75%       70.000000        72.000000       65.000000
# max       97.000000        96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#jointplots

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
#hex diagram groups dots together
#seaborn PLUS

jhex = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='hex')

# %%
#<<<<Chart 1

# %%
jkde = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='kde')

# %% [markdown]
# ---

# %%
#Histograms

# %%
#already know this method
sns.set_style('darkgrid')
m1 = sns.distplot(movies.AudienceRating, bins=15)

# %%
m2 = sns.distplot(movies.CriticRating, bins=15)

# %%
sns.set_style('darkgrid')
n1 = plt.hist(movies.AudienceRating, bins=15)

#INSIGHT - consumer behavior is normal. No criteria being used.

#<<<< chart 2

# %%
sns.set_style('darkgrid')
n1 = plt.hist(movies.CriticRating, bins=15)

#INSIGHT - the behavior of critics is non-normal. 

#<<<< chart 3

# %% [markdown]
# ---

# %%
#Stacked Histograms

# %%
#this code shows them overlayed, but not STACKED

plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
          movies[movies.Genre == 'Drama'].BudgetMillions, \
          movies[movies.Genre == 'Thriller'].BudgetMillions ]\
        ,bins=15, stacked=True)
plt.show()

# %%
###CODING CHALLENGE

#Create a for loop that creates a list containing 
#[movies[movies.Genre == 'Action'].BudgetMillions in order to
#create a histogram plot for all unique genres and their budgets

# %%
for gen in movies.Genre.unique():
    print(gen)
# Out:
# Comedy
# Adventure
# Action
# Horror
# Drama
# Romance
# Thriller

# %%
list1 = list()
mylabels = list()

for gen in movies.Genre.unique():
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)
    
sns.set_style('darkgrid')
h = plt.hist(list1, bins=30, stacked=True, rwidth=.5, label=mylabels)
plt.legend()
plt.show()

# %%
#<<<< CHART 4

# %%
#KDE Plot (kernel density estimate)

#Great for a bi-variate analysis

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre', size=6, aspect=1)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                shade=True, shade_lowest=False, cmap='Reds')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                shade=True, shade_lowest=False, cmap='Reds')

#TIP: adding k1b to layer over it adds smooth edges

k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                cmap='Reds')

# %%
#Working with Subplots()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
f, axes = plt.subplots(2,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0,1])

# %%
f, axes = plt.subplots(1,2, figsize=(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#ViolinPlots

# %%
w = sns.boxplot(data=movies, x='Genre', y='CriticRating')

# %%
#violin plots are like box plots, but their width helps you visually
#see where more observations fall. The width of the violin at a given
#y-point is based on n

z = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
#example of when a violoin plot shows more insights than boxplot

#create a boxplot by year instead of genre
#filter out only Drama moviews

w1 = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
z1 = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
#2008 and 2011 box plots look the same
#2008 and 2011 violin plots have notable differences.

# %% [markdown]
# ---

# %%
#Creating Facet Grids

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
#can populate with any type of chart. 
#example: histograms

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
#back to the scatterplots:
#pass keyword arguments

g = sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)

# %% [markdown]
# ---

# %%
#Controlling Axes and Adding Diagonals

g = sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)
g.set(xlim=(0,100), ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c='gray', ls='--')
g.add_legend()

# %%
#<<<<Chart5

# %% [markdown]
# ---

# %%
#Building Dashboards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('darkgrid')
figure, axes = plt.subplots(3,2, figsize=(20,20))

k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, \
                ax=axes[0,0])

k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, \
                ax=axes[0,1])

z = sns.violinplot(data=movies, x='Genre', y='CriticRating',\
                  ax=axes[1,0])

k4 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                shade=True, shade_lowest=False, cmap='Reds',\
                ax=axes[1,1])

# # #TIP: adding k1b to layer over it adds smooth edges

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 cmap='Reds', ax=axes[1,1])

w1 = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year',\
                 y='CriticRating', ax=axes[2,0])

# jkde = sns.jointplot(data=movies, x='CriticRating', \
#                      y='AudienceRating', kind='kde', ax=axes[2,1])

m2 = sns.distplot(movies.CriticRating, bins=15, ax=axes[2,1])

m1 = sns.distplot(movies.AudienceRating, bins=15, ax=axes[2,1])

# vis1 = sns.lmplot(movies.CriticRating, movies.AudienceRating,\
#                  hue = 'Genre', ax=axes[2,2])


plt.show()

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('white', {'axes.facecolor': "black"})
figure, axes = plt.subplots(3,2, figsize=(30,30))

#Plot[0,0]

k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, \
                 shade=True, shade_lowest=True, cmap='inferno',
                ax=axes[0,0])

k1b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, \
                 cmap='cool', ax=axes[0,0])

#-----FORMATTING-----#
k1.set_title("Audience Rating by Budget", fontsize=24, color='Black', fontname='Roboto')

k1.set_xlabel("Movie Budget ($M)", fontsize=18, color='Black', fontname='Roboto')
k1.set_ylabel("Audience Rating", fontsize=18, color='Black', fontname='Roboto')
k1.tick_params(axis='both',**{'labelsize':18,'pad':10})


#Plot[0,1]

k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, \
                shade=True, shade_lowest=True, cmap='inferno',\
                ax=axes[0,1])

k2b = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, 
                cmap='cool', ax=axes[0,1])

#-----FORMATTING-----#
k2.set_title("Critic Rating by Budget", fontsize=24, \
         color='Black', fontname='Roboto')
k2.set_ylabel("Critic Rating", fontsize=18, color='Black', fontname='Roboto')
k2.set_xlabel("Movie Budget ($M)", fontsize=18, color='Black', fontname='Roboto')
k2.tick_params(axis='both',**{'labelsize':18,'pad':10})

#Plot[1,0]

z = sns.violinplot(data=movies, x='Year', y='BudgetMillions',\
                   palette='GnBu',ax=axes[1,0])

#-----FORMATTING-----#
z.set_title("Movie Budgets by Year", fontsize=24, \
         color='Black', fontname='Roboto')
z.set_ylabel("Movie Budget ($M)", fontsize=18, color='Black', fontname='Roboto')
z.set_xlabel("Year", fontsize=18, color='Black', fontname='Roboto')
z.tick_params(axis='both',**{'labelsize':18,'pad':10})


#Plot[1,1]

k4 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                shade=True, shade_lowest=False, cmap='Blues_r',\
                ax=axes[1,1])

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 cmap='gist_gray_r', ax=axes[1,1])

#-----FORMATTING-----#
k4.set_title("Critic and Audience Rating, KDE", fontsize=24, \
         color='Black', fontname='Roboto')
k4.set_ylabel("Critic Rating", fontsize=18, color='Black', fontname='Roboto')
k4.set_xlabel("Audience Rating", fontsize=18, color='Black', fontname='Roboto')
k4.tick_params(axis='both',**{'labelsize':18,'pad':10})

#Plot[2,0]

w1 = sns.boxplot(data=movies[movies.Genre=='Drama'], y='Year', orient='h',\
                 palette='GnBu', x='CriticRating', ax=axes[2,0], **{'whis':[5,95], \
                'meanline':True, 'width':.35})

#-----FORMATTING-----#
w1.set_title("Critic Rating Dist. for Drama Movies", fontsize=24, \
         color='Black', fontname='Roboto')
w1.set_ylabel("Year", fontsize=18, color='Black', fontname='Roboto')
w1.set_xlabel("Critic Rating (Dramas)", fontsize=18, color='Black', fontname='Roboto')
w1.tick_params(axis='both',**{'labelsize':18,'pad':10})

#Plot[2,1]
m2 = sns.distplot(movies.CriticRating, hist=True, hist_kws={'rwidth':.75}, \
                  bins=15, ax=axes[2,1], color='#8FEF2E')

#-----FORMATTING-----#
m2.set_title("Critic Rating Dist for All Movies", fontsize=24, \
         color='Black', fontname='Roboto')
m2.set_ylabel("Count of Movies", fontsize=18, color='Black', fontname='Roboto')
m2.set_xlabel("Dist. Curve // Hist. Bins = 30", fontsize=18, color='Black', fontname='Roboto')
m2.tick_params(axis='both',**{'labelsize':18,'pad':10})

plt.show()

# %% [markdown]
# ---

# %%
#Thematic Edits (titles, axis formatting, font size, sytling)

# %%
#populate lists for dimensions and measures
#here we need BudgetMillions for each Genre

list1 = list()
mylabels = list()

for gen in movies.Genre.unique():
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

#create subplot workspace
sns.set_style('whitegrid')
fig, ax = plt.subplots() #hack for resizing a single chart
fig.set_size_inches(11.7, 8.27) #size of A4 paper

#add the plot to the workspace
h = plt.hist(list1, bins=30, stacked=True, rwidth=.75, label=mylabels)

#give it a title and axes labels
plt.title("Move Budget Distribution", fontsize=24, \
         color='Black', fontname='Arial')
plt.ylabel("Number of Movies", fontsize=18, color='Black')
plt.xlabel("Movie Budget ($M)", fontsize=18, color='Black')

#format the x and y ticks
plt.yticks(fontsize=14) #you can do a lot with ticks
plt.xticks(fontsize=14)

plt.legend(frameon=True, shadow=True, framealpha=1, prop={'size':14}) #pass a dict to change size
plt.show()

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
type(fig)
# Out:
# matplotlib.figure.Figure
